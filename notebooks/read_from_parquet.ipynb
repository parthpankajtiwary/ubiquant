# %%
import pandas as pd
import numpy as np
import gc

# %%
import seaborn as sns

# %% [markdown]
# #### Global Variables ####

# %%
gc.collect()
# Out:
# 75

# %%
DATA_DIR = '../data/parquet/'

# %% [markdown]
# ##### Read Data #####

# %%
# %%time
train_df = pd.read_parquet(DATA_DIR+'train_low_mem.parquet')
# Out:
# CPU times: user 13.7 s, sys: 31.2 s, total: 44.9 s
# Wall time: 7.82 s

# %%
train_df.head(2)
# Out:
#   row_id  time_id  investment_id    target       f_0       f_1       f_2  \
# 0    0_1        0              1 -0.300875  0.932573  0.113691 -0.402206
# 1    0_2        0              2 -0.231040  0.810802 -0.514115  0.742368
#
#         f_3       f_4       f_5  ...     f_290     f_291     f_292     f_293  \
# 0  0.378386 -0.203938 -0.413469  ...  0.366028 -1.095620  0.200075  0.819155
# 1 -0.616673 -0.194255  1.771210  ... -0.154193  0.912726 -0.734579  0.819155
#
#       f_294     f_295     f_296     f_297     f_298     f_299
# 0  0.941183 -0.086764 -1.087009 -1.044826 -0.287605  0.321566
# 1  0.941183 -0.387617 -1.087009 -0.929529 -0.974060 -0.343624
#
# [2 rows x 304 columns]

# %%
agg1 = train_df.groupby('investment_id',as_index=False).agg(avg = ('target', np.mean))

# %%
agg2 = train_df.groupby('time_id',as_index=False).agg(avg = ('target', np.mean))

# %%
sns.scatterplot(data=agg2, x="time_id", y="avg")
# Out:
# <AxesSubplot:xlabel='time_id', ylabel='avg'>

# %%
sns.scatterplot(data=agg1, x="investment_id", y="avg")
# Out:
# <AxesSubplot:xlabel='investment_id', ylabel='avg'>
